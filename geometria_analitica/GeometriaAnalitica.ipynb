# %% [markdown]
# # Geometria Analitica

# %% [markdown]
# ## Risorse utili da cui ho preso spunto per produrre questi appunti:
# https://youtube.com/playlist?list=PLZHQObOWTQDPD3MizzM2xVFitgF8hE_ab&si=Xg0vBhr5vt4ourYg

# %% [markdown]
# ## Vettori

# %% [markdown]
# ### Definizione
#
# Non esiste una definizione precisa di vettore.\
# Esistono infatti diverse scuole di pensiero su che cosa sia il vettore:
#
# **Prospettiva dello studente di fisica:**\
# Un vettore è una line caratterizzata dalla sua **direzione** e dal **verso** un cui punta.\
# Questa linea può essere piazzata su un piano (vettore bidimensionale) o nello spazio (vettore tridimensionale).
#
# **Prospettiva dello studente di informatica:**\
# Un vettore non è altro che un sinonimo di lista.\
# La dimensione del vettore, quando considerato da questa prospettiva, è la sua lunghezza.
#
# **Prospettiva dello studente di matematica:**\
# Quest'ultima prospettiva , è un'astrazione tra le due prospettive viste in precedenza.\
# Per ora è meglio ignorare la definizione puramente matematica di vettore, per riuscire a creare un'intuizione utilizzando le due prospettive più semplici già prese in considerazione.
#
# **Osservazioni:**\
# Indipendentemente dal punto di vista che vogliamo considerare, un vettore, per poter avere significato, ha bisogno di un sistema di coordinate (sia che sia una freccia, sia che sia una lista di valori).

# %% [markdown]
# ### Rappresentazione di un vettore
# Per distinguere un vettore da un punto, la sua rappresentazione consiste da una serie di valori ordinati verticalmente dal primo all'ultimo e racchiusi da due parentesi graffe.
# $$
# \vec{v} = \begin{bmatrix}
# v_1 \\
# v_2 \\
# \vdots \\
# v_n
# \end{bmatrix}
# $$

# %% [markdown]
# ### Operazioni sui vettori

# %% [markdown]
# #### Somma di vettori
#
# **Prospettica geometrica:**\
# Per rappresentare la somma di due vettori, si considerano tutti i vettori e li si traslano in modo tale che la coda del vettore corrente coincida con la punta del vettore precedente.\
# Per visualizzare la somma tra tutti questi vettori basterà tracciare il vettore ottenuto tracciando una linea dalla coda del primo alla punta dell'ultimo.
#
# > somma di due vettori\
# > \
# > ![image.png](attachment:image.png)
#
# **Prospettiva algebrica:**\
# La somma di vettori è definita dalla seguente formula:
# $$
# \begin{bmatrix}
# a\\
# b\\
# \end{bmatrix}
# +
# \begin{bmatrix}
# c\\
# d\\
# \end{bmatrix}
# =
# \begin{bmatrix}
# a+c\\
# b+d\\
# \end{bmatrix}
# $$
#
# Esempio
# $$
# \begin{bmatrix}
# 1\\
# 2\\
# \end{bmatrix}
# +
# \begin{bmatrix}
# 3\\
# -1\\
# \end{bmatrix}
# =
# \begin{bmatrix}
# 1+3\\
# 2+(-1)\\
# \end{bmatrix}
# =
# \begin{bmatrix}
# 4\\
# 1\\
# \end{bmatrix}
# $$

# %% [markdown]
# ##### Proprietà della somma di vettori
# 1. Proprietà commutativa: $\vec{v} + \vec{w} = \vec{w} + \vec{v}$

# %% [markdown]
# #### Moltiplicazione tra un valore scalare e un vettore
#
# **Prospettiva geometrica:**\
# Per moltiplicazione tra un valore scalare e un vettore, si intende l'operazione che prende in input un vettore ed un numero, il risultato sarà un vettore giacente sulla stessa retta di quello di partenza e con lunghezza uguale al prodotto tra la lunghezza del vettore di partenza e il valore scalare.
#
# > Prodotto tra due vettori\
# > \
# > ![image.png](attachment:image.png)
#
# **Prospettiva algbrica:**\
# La moltiplicazione tra uno scalare ed un vettore, è definita dalla seguente formula:
# $$
# k \cdot
# \begin{bmatrix}
# a\\
# b\\
# \end{bmatrix}
# =
# \begin{bmatrix}
# k \cdot a\\
# k \cdot b\\
# \end{bmatrix}
# $$
#
# Esempio:
# $$
# 2 \cdot
# \begin{bmatrix}
# 3\\
# 1\\
# \end{bmatrix}
# =
# \begin{bmatrix}
# 2 \cdot 3\\
# 2 \cdot 1\\
# \end{bmatrix}
# =
# \begin{bmatrix}
# 6\\
# 2\\
# \end{bmatrix}
# $$
#
# **Osservazioni:**
# - Quando si moltiplica un vettore per un valore scalare negativo, si ottiene un vettore che punta nella direzione opposta rispetto a quello di partenza.
# - Nell'algebra lineare, un'operazione che fanno spesso i numeri è quella di scalare dei vettori, per questo, quando un numero è atto a compiere questa operazione, è comune prenda il nome di "scalare"

# %% [markdown]
# ### Vettori Speciali
#
# Esistono due vettori particolari (considerando un sistema di riferimento bidimensionale), chiamati rispettivamente $\hat{i}$ e $\hat{j}$, essi sono rispettivamente il vettore di lunghezza 1 verso destra che giace sull'asse delle ascisse (x) e il vettore di lunghezza 1 verso l'alto che giacce sull'asse delle ordinate (y).\
# Questi due vettori speciali sono anche chiamati "vettori di base".
#
# > Vettori $\hat{i}$ e $\hat{j}$\
# > \
# > ![image.png](attachment:image.png)
#
# Questi due vettori particolari sono importantissimi perché definiscono il sistema di riferimento.\
# Prendiamo in considerazione il vettore $\begin{bmatrix}5\\3\end{bmatrix}$ e invece di immaginarlo come il semplice vettore dato dalla coordinata x=5 e y=3, dal prodotto scalare di $\hat{i}$ e $5$ associato al prodotto scalare tra $\hat{j}$ e $3$:
# $$
# \vec{v} = \begin{bmatrix}5 \cdot \hat{i}\\3 \cdot \hat{j}\end{bmatrix}
# $$
#
# Per ora questo ragionamento sembra un'inutile complicazione.\
# Consideriamo però un'altra cosa:\
# Ma se si potessero cambiare i valori iniziali di $\hat{i}$ e $\hat{j}$?\
# Cambiando questi valori possiamo alterare il sistema di coordinate a nostro piacimento.

# %% [markdown]
# #### Il vettore nullo
# Per indicare il vettore nullo, in questi appunti utilizzerò il simbolo $\vec{0}$

# %% [markdown]
# ### Relazioni tra vettori

# %% [markdown]
# #### Combinazione lineare tra due vettori
#
# La combinazione lineare tra due vettori non è altro che la somma tra due vettori, ognuno moltiplicato per uno scalare (che può essere uguale o diverso tra i due vettori).
# $$
# x \cdot \vec{v} + y \cdot \vec{w}
# $$

# %% [markdown]
# #### Lo spazio generato tra due vettori | Span di due vettori
# Lo span di due vettori, o spazio generato tra due vettori è l'insieme di tutti i vettori ottenibili eseguendo una combinazione lineare tra due vettori.\
# Tendenzialmente si possono raggiungere tutti i vettori del sistema di riferimento, tranne in alcuni casi:
# - Alcuni dei vettori considerati giacciono sulla stessa retta
# - Alcuni dei vettori considerati sono nulli (punto di partenza uguale al punto di arrivo)

# %% [markdown]
# ## Il piano nello spazio
#
# Il piano nello spazio ha un'equazione molto simile a quella della retta nel piano:
# $$
# ax+by+cx= d
# $$
# in questa equazione, $a$, $b$, $c$ e $d$ sono numeri reali; $x$, $y$ e $z$ sono le coordinate dei punti che giacciono sul piano descritto dall'equazione.

# %% [markdown]
# ## La retta

# %% [markdown]
# ### Nel piano
# La retta nel piano può essere rappresentata in diverse forme:
#
# **Esplicita:**
# $$
# y= mx + q
# $$
# Dove $x$ e $y$ sono le coordinate dei punti che giacciono sulla retta stessa, e $m$ e $q$ sono coefficienti reali.\
# \
# \
# **Implicita:**
# $$
# ax+by+x= 0
# $$
# Dove $x$ e $y$ sono le coordinate dei punti che giacciono sulla retta stessa, e $m$ e $q$ sono coefficienti reali.\
# \
# \
# **Parametrica:**
# $$
# \begin{cases}
# x = x_0 + t \cdot v_x \\
# y = y_0 + t \cdot v_y
# \end{cases}
# $$
# Dove $x$ e $y$ sono le coordinate dei punti che giacciono sulla retta stessa, $x_0$ e $y_0$ sono le coordinate di un punto dal quale la retta passa, e $v_x$ e $v_y$ sono le componenti del vettore direttore (che descrive la direzione della retta).ù

# %% [markdown]
# ### Nello spazio
#
# **Intersezione tra due piani:**\
# Nello spazio la situazione cambia leggermente: non si può più rappresentare una retta con una singola forma implicita o esplicita "su una riga".\
# Per capire affondo questo concetto è necessario pensare alla retta come l'intersezione tra due piani, per ottenerla quindi dovremmo mettere a sistema le equazioni descriventi due piani (vedi sezione "Il piano nello spazio" per la rappresentazione matematica del piano nello spazio).
# $$
# \begin{cases}
# a_1x + b_1y + c_1z = d_1\\
# a_2x + b_2y + c_2z = d_2
# \end{cases}
# $$
# In questa equazione (usata meno comunemente rispetto a quella che spiegherò di seguito), rappresenta l'intersezione di tutti i punti racchiusi nel primo ($a_1x + b_1y + c_1z = d_1$) e nel secondo ($a_2x + b_2y + c_2z = d_2$) piano.
#
# **Equazione parametrica:**\
# L'equazione parametrica, viene estrapolata da due entità:
# - Un punto dal quale la retta passa
# - Un direttore (un vettore direzionale)
# $$
# \begin{cases}
# x= x_0 + tv_x\\
# y= y_0 + tv_y\\
# z= z_0 + tv_z
# \end{cases}
# $$
# In questa equazione, $x_0$, $y_0$ e $z_0$ sono le coordinate di un punto sulla retta; $v_x$, $v_y$ e $v_z$ sono le componenti del direttore che descrive il verso nel quale la retta si sviluppa. $t$ è un numero reale, può essere immaginato come un "cursore", che quando aumentato o diminuito restituisce le coordinate del punto sul quale si trova.

# %% [markdown]
# ## Area del parallelogramma composto da 2 vettori geometrici

# %% [markdown]
# ### Nel piano:
# $A = |v_1 w_2 - v_2 w_1|$
#
# **Osservazione:**\
# L'oridine in cui calcolo l'area utilizzando la formula sopra, l'area risulterà negativa.

# %% [markdown]
# ### Nello spazio
# $|\vec{v}||\vec{w}|-(\vec{} \cdot \vec{})$

# %% [markdown]
# ### Prodotto vettoriale
# $\vec{v} per \vec{w}$

# %% [markdown]
# ## Utility programmatica per risolvere eventuali esercizi

# %%
from abc import ABC, abstractmethod

class Point(ABC):
    @abstractmethod
    def get_coords_list(self) -> list:
        """
        This method returns a list of numbers representing the coordinates of the points
        """
        pass

class Point2D(Point):
    def __init__(self, x, y) -> None:
        self.x= x
        self.y= y

    def get_coords_list(self) -> list:
        return [self.x, self.y]

class Point3D(Point):
    def __init__(self, x, y, z) -> None:
        self.x= x
        self.y= y
        self.z= z

    def get_coords_list(self) -> list:
        return [self.x, self.y, self.z]

class Vector:
    def __init__(self, start: Point, end: Point) -> None:
        if type(start) != type(end):
            raise TypeError(f"Start ({type(start).__name__}) and End ({type(end).__name__}) points must be of the same type.")

        self.start= start
        self.end= end

    def __add__(self, other: "Vector") -> "Vector":
        """
        Sums two vectors in an n-dimensional space system
        """

        if type(self) != type(other):
            raise TypeError(f"Cannot sum two vectors belonging to different reference systems")

        # Adapting the coordinates
        self_magnitude= [end-start for start, end in zip(self.end.get_coords_list(), self.start.get_coords_list())]
        other_vector_magnitude= [end-start for start, end in zip(other.end.get_coords_list(), other.start.get_coords_list())]
        result_coords = [a + b for a, b in zip(self_magnitude, other_vector_magnitude)]
        return type(self)(self.start, type(self.start)(*result_coords))

    def _scalar_multiplication(self, scalar: int|float) -> "Vector":
        """
        Multiplies a vector by a scalar
        """

        result_start_coords= [c*scalar for c in self.start.get_coords_list()]
        result_end_coords= [c*scalar for c in self.end.get_coords_list()]
        return type(self)(type(self.start)(*result_start_coords), type(self.end)(*result_end_coords))

    def _vector_multiplication(self, other: "Vector") -> "Vector":
        """
        Multiplies two vectors
        """
        pass

    def __mul__(self, multiplier) -> "Vector":
        """
        Multiplies a vector by a scalar or another vector

        Args:
            multiplier: int|float|Vector
                The scalar or vector to multiply the current vector with

        Returns:
            Vector
                The result of the multiplication

        Raises:
            TypeError: If the multiplier is not an int, float or Vector
        """

        if (isinstance(multiplier, int) or isinstance(multiplier, float)):
            return self._scalar_multiplication(multiplier)
        elif isinstance(multiplier, Vector):
            return self._vector_multiplication(multiplier)
        else:
            raise TypeError(f"Cannot multiply a vector by a {type(multiplier).__name__}")

    def __str__(self) -> str:
        return f"Vector:\n\tstart: {str(self.start.get_coords_list())}\n\tend: {str(self.end.get_coords_list())}"

class Vector2D(Vector):
    def __init__(self, start, end):
        super().__init__(start, end)

class Vector3D(Vector):
    def __init__(self, start, end):
        super().__init__(start, end)


###                ###
### Usage examples ###
###                ###

# Initializing the first vector
A= Point2D(1, 2)
B= Point2D(4, 5)
AB= Vector2D(A, B)

# Initializing the second vector
C= Point2D(3, 4)
D= Point2D(3, 7)
CD= Vector2D(C, D)

# Calculating the sum of the two vectors
AD= AB+CD
print(AD)

# Calculating the product between a scalar and a vector
print(AD*2)
# Out:
# Vector:
# 	start: [1, 2]
# 	end: [-3, -6]
# Vector:
# 	start: [2, 4]
# 	end: [-6, -12]

# %% [markdown]
# ## Esercizi

# %% [markdown]
# ### 1.1 Determinare la forma parametrica e cartesiana della retta del piano

# %% [markdown]
# #### (a) Passante per i punti $A(1, 2)$ e $B(−1, 3)$.

# %% [markdown]
# **Equazione Cartesiana:**
#
# Formula generale:
#
# $
# \begin{cases}
# x= x_0 \cdot m + q\\
# y= y_0 \cdot m + q
# \end{cases}
# $
#
# ---
# Soluzione:
#
# $
# \begin{cases}
# 2= m + q\\
# 3= -m + q
# \end{cases}
# $
#
# $
# \begin{cases}
# m= 2 - q\\
# 3= -m + q
# \end{cases}
# $
#
# $
# \begin{cases}
# m= 2 - q\\
# 3= -(2 - q) + q
# \end{cases}
# $
#
# $
# \begin{cases}
# m= 2 - q\\
# q= \frac{5}{2}
# \end{cases}
# $
#
# $
# \begin{cases}
# m= -\frac{1}{2}\\
# q= \frac{5}{2}
# \end{cases}
# $
#
# $
# y= -\frac{1}{2}x+\frac{5}{2}
# $
#
# **Equazione Parametrica:**
#
# Formula generale:
#
# $
# \begin{cases}
# x= x_0 + t \cdot v_x\\
# y= y_0 + t \cdot v_y
# \end{cases}
# $
#
# ---
#
# $
# \vec{v}= ((x_1-x_0), (y_1-y_0))\\
# \vec{v}= ((-1-1), (3-2)) = (-2, 1)
# $
#
# $
# \begin{cases}
# x= 1 + t \cdot -2\\
# y= 2 + t \cdot 1
# \end{cases}
# $
#
# $
# \begin{cases}
# x= 1 -2t\\
# y= 2 + t
# \end{cases}
# $

# %% [markdown]
# #### (b) Passante per $C(2, 3)$ e parallela al vettore $\vec{OP}=(-1, 2)$.

# %% [markdown]
# **Equazione parametrica:**
#
# $
# \begin{cases}
# x= 2 - t\\
# y= 3 + 2t
# \end{cases}
# $
#
# **Equazione cartesiana:**
#
# Trovo due punti tra i quali passa la retta:
# $C(2, 3)$
# $D= C + \vec{OP}= ((2-1), (3+2)) = (1, 5)$
#
# $
# \begin{cases}
# 3= 2m + q\\
# 5= m + q
# \end{cases}
# $
#
# $[...]$
#
# $
# y= -2x + 7
# $

# %% [markdown]
# #### (c) Di equazione cartesiana y = 2x + 5. Determinare inoltre un punto appartenente a tale retta.

# %% [markdown]
# **Equazione Parametrica:**
# Calcoliamo un punto da cui passa:\
# Poniamo $x=0$\
# $y= 5$\
# $A(0, 5)$
#
# Calcoliamo il direttore $\vec{v}$ (si vede dall'equazione):\
# $\vec{v} = (1, 2)$
#
# $
# \begin{cases}
# x= t\\
# y= 1 + 2t
# \end{cases}
# $

# %% [markdown]
# ### 1.2 Determinare la forma parametrica e cartesiana della retta dello spazio

# %% [markdown]
# #### (a) Passante per i punti $A(1, 0, 2)$ e $B(3, −1, 0)$.

# %% [markdown]
# **Forma cartesiana:**
#
# ❗❗❗Non so come ricavare la forma cartesiana di una retta nello spazio❗❗❗
#
# **Forma parametrica:**
#
# Trovo il direttore:\
# $\vec{v} = A-B = ((3-1), (-1-0), (0-2)) = (2, -1, -2)$
#
# $
# \begin{cases}
# x = 1 + 2t\\
# y = 0 - t\\
# z = 2 - 2t
# \end{cases}
# $
#
# $
# \begin{cases}
# t = \frac{-1 + x}{2}\\
# y = \frac{1 - x}{2}\\
# z = 3 - x
# \end{cases}
# $
#
# $
# \begin{cases}
# y = \frac{1 - x}{2}\\
# z = 3 - x
# \end{cases}
# $

# %% [markdown]
# #### (b) Passante per il punto $P(1, 3, 1)$ e parallela al vettore $\vec{OQ} = (2, 0, 0)$.

# %% [markdown]
# #### (c) Di equazioni cartesiane
# $
# \begin{cases}
# y = 3x + 1\\
# y − x + z = 0
# \end{cases}
# $
# #### Determinare inoltre un punto appartenente a tale retta.

# %% [markdown]
# ### 1.3 Sia $r$ la retta di $R^3$ passante per i punti $A(1, −1, 2)$ e $B(−2, 0, 1)$, e sia $s$ la retta contenente $C(1, 3, −3)$ e parallela al vettore $\vec{OD}=(2, −2, 3)$
